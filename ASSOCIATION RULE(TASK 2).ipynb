# %% [markdown]
# # Importing the required Libraries

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# Loading the Dataset from the local machine

# %%
df = pd.read_excel(r'C:\Users\user\Downloads\Online Retail.xlsx')

# %% [markdown]
# Performing EDA on the Data

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# Removing the extra spaces in the Description column

# %%
df['Description'] = df['Description'].str.strip()

# %% [markdown]
# Dropping all the rows with no Invoice Number

# %%
df.dropna(axis = 0, subset = ['InvoiceNo'], inplace = True)

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# Converting the Invoice Column to String Data type

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# Dropping all rows that contain goods bought on credit

# %%
df = df[~df['InvoiceNo'].str.contains('C')]

# %% [markdown]
# checking the Dataset structure after dropping the rows

# %%
df.shape
# Out:
# (532621, 8)

# %%
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# 0            False    False
# 1            False    False
# 2            False    False
# 3            False    False
# 4            False    False
# ...            ...      ...
# 541904       False    False
# 541905       False    False
# 541906       False    False
# 541907       False    False
# 541908       False    False
#
# [532621 rows x 8 columns]

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  532621.000000  532621.000000  397924.000000
# mean       10.239972       3.847621   15294.315171
# std       159.593551      41.758023    1713.169877
# min     -9600.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %% [markdown]
# # Splitting the Dataset with respect to the countries

# %%
basket_France = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Netherlands = (df[df['Country'] =="Netherlands"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Germany = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_EIRE = (df[df['Country'] =="EIRE"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Spain = (df[df['Country'] =="Spain"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Portugal = (df[df['Country'] =="Portugal"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Belgium = (df[df['Country'] =="Belgium"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Finland = (df[df['Country'] =="Finland"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_Sweden = (df[df['Country'] =="Sweden"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %% [markdown]
# # Encoding the Data

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

# %% [markdown]
# The above is done to make the data suitable for the library used in the study

# %% [markdown]
# #  Encoding dataset and Building the Apriori Association Rule Mining Model for the some selected Countries based on their region

# %%
basket_encoded = basket_France.applymap(hot_encode)
basket_France = basket_encoded

# %%
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 300  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                          consequents  antecedent support  consequent support  \
# 45                         (POSTAGE)            0.076531            0.765306
# 258                        (POSTAGE)            0.051020            0.765306
# 270                        (POSTAGE)            0.053571            0.765306
# 300  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 302    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 45   0.076531       1.000  1.306667  0.017961         inf
# 258  0.051020       1.000  1.306667  0.011974         inf
# 270  0.053571       1.000  1.306667  0.012573         inf
# 300  0.099490       0.975  7.644000  0.086474   34.897959
# 302  0.099490       0.975  7.077778  0.085433   34.489796

# %%
basket_encoded = basket_Netherlands.applymap(hot_encode)
basket_Netherlands = basket_encoded

# %%
frq_items = apriori( basket_Netherlands, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                             antecedents  \
# 650                 (FOLDING BUTTERFLY MIRROR HOT PINK)
# 651                      (FOLDING BUTTERFLY MIRROR RED)
# 1352  (FOOD CONTAINER SET 3 LOVE HEART, CARD DOLLY G...
# 1353                           (10 COLOUR SPACEBOY PEN)
# 1382  (STRAWBERRY LUNCH BOX WITH CUTLERY, CARD DOLLY...
#
#                                             consequents  antecedent support  \
# 650                      (FOLDING BUTTERFLY MIRROR RED)            0.052632
# 651                 (FOLDING BUTTERFLY MIRROR HOT PINK)            0.052632
# 1352                           (10 COLOUR SPACEBOY PEN)            0.052632
# 1353  (FOOD CONTAINER SET 3 LOVE HEART, CARD DOLLY G...            0.052632
# 1382                           (10 COLOUR SPACEBOY PEN)            0.052632
#
#       consequent support   support  confidence  lift  leverage  conviction
# 650             0.052632  0.052632         1.0  19.0  0.049861         inf
# 651             0.052632  0.052632         1.0  19.0  0.049861         inf
# 1352            0.052632  0.052632         1.0  19.0  0.049861         inf
# 1353            0.052632  0.052632         1.0  19.0  0.049861         inf
# 1382            0.052632  0.052632         1.0  19.0  0.049861         inf

# %%
basket_encoded = basket_Germany.applymap(hot_encode)
basket_Germany = basket_encoded

# %%
frq_items = apriori( basket_Germany, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents consequents  \
# 34                         (PLASTERS IN TIN STRONGMAN)   (POSTAGE)
# 50                   (RETROSPOT TEA SET CERAMIC 11 PC)   (POSTAGE)
# 52                 (ROUND SNACK BOXES SET OF 4 FRUITS)   (POSTAGE)
# 102  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...   (POSTAGE)
# 32                          (PLASTERS IN TIN SPACEBOY)   (POSTAGE)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 34             0.070022            0.818381  0.067834    0.968750  1.183740
# 50             0.056893            0.818381  0.054705    0.961538  1.174928
# 52             0.157549            0.818381  0.150985    0.958333  1.171012
# 102            0.131291            0.818381  0.124726    0.950000  1.160829
# 32             0.107221            0.818381  0.100656    0.938776  1.147113
#
#      leverage  conviction
# 34   0.010529    5.811816
# 50   0.008145    4.722101
# 52   0.022049    4.358862
# 102  0.017280    3.632385
# 32   0.012909    2.966448

# %%
basket_encoded = basket_EIRE.applymap(hot_encode)
basket_EIRE = basket_encoded

# %%
frq_items = apriori( basket_EIRE, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 195  (REGENCY TEA PLATE PINK, REGENCY CAKESTAND 3 T...
# 184   (REGENCY TEAPOT ROSES, REGENCY CAKESTAND 3 TIER)
# 116  (GREEN REGENCY TEACUP AND SAUCER, REGENCY CAKE...
# 128  (REGENCY SUGAR BOWL GREEN, GREEN REGENCY TEACU...
# 140  (GREEN REGENCY TEACUP AND SAUCER, REGENCY TEAP...
#
#                            consequents  antecedent support  \
# 195          (REGENCY TEA PLATE GREEN)            0.055556
# 184         (REGENCY SUGAR BOWL GREEN)            0.052083
# 116  (ROSES REGENCY TEACUP AND SAUCER)            0.086806
# 128  (ROSES REGENCY TEACUP AND SAUCER)            0.062500
# 140  (ROSES REGENCY TEACUP AND SAUCER)            0.052083
#
#      consequent support   support  confidence       lift  leverage  conviction
# 195            0.079861  0.055556         1.0  12.521739  0.051119         inf
# 184            0.086806  0.052083         1.0  11.520000  0.047562         inf
# 116            0.166667  0.086806         1.0   6.000000  0.072338         inf
# 128            0.166667  0.062500         1.0   6.000000  0.052083         inf
# 140            0.166667  0.052083         1.0   6.000000  0.043403         inf

# %%
basket_encoded = basket_Spain.applymap(hot_encode)
basket_Spain = basket_encoded

# %%
frq_items = apriori( basket_Spain, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 240     (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)
# 245                          (LUNCH BAG  BLACK SKULL.)
# 64                    (PINK REGENCY TEACUP AND SAUCER)
# 85                           (LUNCH BAG  BLACK SKULL.)
# 235  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
#
#                                         consequents  antecedent support  \
# 240                       (LUNCH BAG  BLACK SKULL.)            0.055556
# 245  (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)            0.055556
# 64                (GREEN REGENCY TEACUP AND SAUCER)            0.055556
# 85                            (LUNCH BAG CARS BLUE)            0.055556
# 235               (GREEN REGENCY TEACUP AND SAUCER)            0.055556
#
#      consequent support   support  confidence  lift  leverage  conviction
# 240            0.055556  0.055556         1.0  18.0  0.052469         inf
# 245            0.055556  0.055556         1.0  18.0  0.052469         inf
# 64             0.066667  0.055556         1.0  15.0  0.051852         inf
# 85             0.066667  0.055556         1.0  15.0  0.051852         inf
# 235            0.066667  0.055556         1.0  15.0  0.051852         inf

# %%
basket_encoded = basket_Portugal.applymap(hot_encode)
basket_Portugal = basket_encoded

# %%
frq_items = apriori( basket_Portugal, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                               antecedents                         consequents  \
# 1170     (SET 12 COLOUR PENCILS SPACEBOY)  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1171   (SET 12 COLOUR PENCILS DOLLY GIRL)    (SET 12 COLOUR PENCILS SPACEBOY)
# 1172   (SET 12 COLOUR PENCILS DOLLY GIRL)  (SET OF 4 KNICK KNACK TINS LONDON)
# 1173   (SET OF 4 KNICK KNACK TINS LONDON)  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1174  (SET OF 4 KNICK KNACK TINS POPPIES)  (SET 12 COLOUR PENCILS DOLLY GIRL)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 1170            0.051724            0.051724  0.051724         1.0  19.333333
# 1171            0.051724            0.051724  0.051724         1.0  19.333333
# 1172            0.051724            0.051724  0.051724         1.0  19.333333
# 1173            0.051724            0.051724  0.051724         1.0  19.333333
# 1174            0.051724            0.051724  0.051724         1.0  19.333333
#
#       leverage  conviction
# 1170  0.049049         inf
# 1171  0.049049         inf
# 1172  0.049049         inf
# 1173  0.049049         inf
# 1174  0.049049         inf

# %%
basket_encoded = basket_Belgium.applymap(hot_encode)
basket_Belgium = basket_encoded

# %%
frq_items = apriori( basket_Belgium, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                    antecedents  \
# 426              (SET/6 RED SPOTTY PAPER CUPS)
# 427            (SET/6 RED SPOTTY PAPER PLATES)
# 1383    (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)
# 1384  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 1385             (SET/6 RED SPOTTY PAPER CUPS)
#
#                                    consequents  antecedent support  \
# 426            (SET/6 RED SPOTTY PAPER PLATES)             0.05102
# 427              (SET/6 RED SPOTTY PAPER CUPS)             0.05102
# 1383           (SET/6 RED SPOTTY PAPER PLATES)             0.05102
# 1384             (SET/6 RED SPOTTY PAPER CUPS)             0.05102
# 1385  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)             0.05102
#
#       consequent support  support  confidence  lift  leverage  conviction
# 426              0.05102  0.05102         1.0  19.6  0.048417         inf
# 427              0.05102  0.05102         1.0  19.6  0.048417         inf
# 1383             0.05102  0.05102         1.0  19.6  0.048417         inf
# 1384             0.05102  0.05102         1.0  19.6  0.048417         inf
# 1385             0.05102  0.05102         1.0  19.6  0.048417         inf

# %%
basket_encoded = basket_Sweden.applymap(hot_encode)
basket_Sweden = basket_encoded

# %%
frq_items = apriori( basket_Sweden, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                            antecedents                     consequents  \
# 0        (12 PENCILS SMALL TUBE SKULL)   (PACK OF 72 SKULL CAKE CASES)
# 1        (PACK OF 72 SKULL CAKE CASES)   (12 PENCILS SMALL TUBE SKULL)
# 4              (36 DOILIES DOLLY GIRL)  (ASSORTED BOTTLE TOP  MAGNETS)
# 5       (ASSORTED BOTTLE TOP  MAGNETS)         (36 DOILIES DOLLY GIRL)
# 180  (CHILDRENS CUTLERY CIRCUS PARADE)  (CHILDRENS CUTLERY DOLLY GIRL)
#
#      antecedent support  consequent support   support  confidence  lift  \
# 0              0.055556            0.055556  0.055556         1.0  18.0
# 1              0.055556            0.055556  0.055556         1.0  18.0
# 4              0.055556            0.055556  0.055556         1.0  18.0
# 5              0.055556            0.055556  0.055556         1.0  18.0
# 180            0.055556            0.055556  0.055556         1.0  18.0
#
#      leverage  conviction
# 0    0.052469         inf
# 1    0.052469         inf
# 4    0.052469         inf
# 5    0.052469         inf
# 180  0.052469         inf

# %%
basket_encoded = basket_Finland.applymap(hot_encode)
basket_Finland = basket_encoded

# %%
frq_items = apriori( basket_Finland, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                              antecedents  \
# 2   (PACK OF 60 PINK PAISLEY CAKE CASES)
# 3          (60 TEATIME FAIRY CAKE CASES)
# 16    (SET 3 RETROSPOT TEA,COFFEE,SUGAR)
# 17            (CAKE PLATE LOVEBIRD PINK)
# 62  (SET OF 60 PANTRY DESIGN CAKE CASES)
#
#                              consequents  antecedent support  \
# 2          (60 TEATIME FAIRY CAKE CASES)            0.073171
# 3   (PACK OF 60 PINK PAISLEY CAKE CASES)            0.073171
# 16            (CAKE PLATE LOVEBIRD PINK)            0.073171
# 17    (SET 3 RETROSPOT TEA,COFFEE,SUGAR)            0.073171
# 62                 (MINT KITCHEN SCALES)            0.073171
#
#     consequent support   support  confidence       lift  leverage  conviction
# 2             0.073171  0.073171         1.0  13.666667  0.067817         inf
# 3             0.073171  0.073171         1.0  13.666667  0.067817         inf
# 16            0.073171  0.073171         1.0  13.666667  0.067817         inf
# 17            0.073171  0.073171         1.0  13.666667  0.067817         inf
# 62            0.073171  0.073171         1.0  13.666667  0.067817         inf
